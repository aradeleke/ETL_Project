# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#datasource is US depart of labor - www.dol.gov
csv_file = "Resources/Labor_force.csv"
unemployment_data_df = pd.read_csv(csv_file)
unemployment_data_df.head()
# Out:
#                        State  IUR%  TUR%  Covered Employment  Labor Force  \
# 0  Alabama                     0.7   2.5                1,937       2,260
# 1  Alaska                      2.4   5.9                  314         343
# 2  Arizona                     0.6   4.3                2,818       3,611
# 3  Arkansas                    0.8   3.3                1,204       1,368
# 4  California                  1.7   3.7               17,392      19,598
#
#   Total Unemployment Insured Unemployment Total Unemployed
# 0               55.9                 14.3             14.3
# 1               20.2                  7.8              7.8
# 2              155.4                 17.4             17.4
# 3               44.6                 10.0             10.0
# 4              719.3                301.9            301.9

# %%
new_unemployment_data_df = unemployment_data_df[['State','Labor Force','Total Unemployment','Insured Unemployment']].copy()
new_unemployment_data_df.head()
# Out:
#                        State Labor Force Total Unemployment  \
# 0  Alabama                         2,260               55.9
# 1  Alaska                            343               20.2
# 2  Arizona                         3,611              155.4
# 3  Arkansas                        1,368               44.6
# 4  California                     19,598              719.3
#
#   Insured Unemployment
# 0                 14.3
# 1                  7.8
# 2                 17.4
# 3                 10.0
# 4                301.9

# %%
#unemployment_data_df = unemployment_data_df.reindex(columns=['State', 'IUR%', 'TUR%', 'Covered Employment', 'Total Unemployment'])

# %%
csv_file1 = "Resources/allhlcn191.csv"
employment_data1 = pd.read_csv(csv_file1)
employment_data1.head()
# Out:
#   Area\nCode  St  Cnty  Own  NAICS  Year  Qtr Area Type St Name        Area  \
# 0      US000  US   0.0    0     10  2019    1    Nation     NaN  U.S. TOTAL
# 1      US000  US   0.0    1     10  2019    1    Nation     NaN  U.S. TOTAL
# 2      US000  US   0.0    2     10  2019    1    Nation     NaN  U.S. TOTAL
# 3      US000  US   0.0    3     10  2019    1    Nation     NaN  U.S. TOTAL
# 4      US000  US   0.0    5     10  2019    1    Nation     NaN  U.S. TOTAL
#
#    ...                  Industry Status Code Establishment Count  \
# 0  ...  10 Total, all industries         NaN          10,128,767
# 1  ...  10 Total, all industries         NaN              59,786
# 2  ...  10 Total, all industries         NaN              69,738
# 3  ...  10 Total, all industries         NaN             170,833
# 4  ...  10 Total, all industries         NaN           9,828,410
#
#   January Employment February Employment March Employment  \
# ...

# %%
new_employment_data1 = employment_data1[['Area Type','St Name','Industry','Establishment Count','Total Quarterly Wages']].copy()
new_employment_data1.head()
# Out:
#   Area Type St Name                  Industry Establishment Count  \
# 0    Nation     NaN  10 Total, all industries          10,128,767
# 1    Nation     NaN  10 Total, all industries              59,786
# 2    Nation     NaN  10 Total, all industries              69,738
# 3    Nation     NaN  10 Total, all industries             170,833
# 4    Nation     NaN  10 Total, all industries           9,828,410
#
#   Total Quarterly Wages
# 0     2,244,801,047,986
# 1        55,405,534,148
# 2        71,755,772,878
# 3       188,105,800,263
# 4     1,929,533,940,697

# %%
csv_file2 = "Resources/allhlcn192.csv"
employment_data2 = pd.read_csv(csv_file2)
employment_data2.head()
# Out:
#   Area\nCode  St  Cnty  Own  NAICS  Year  Qtr Area Type St Name        Area  \
# 0      US000  US   0.0    0     10  2019    2    Nation     NaN  U.S. TOTAL
# 1      US000  US   0.0    1     10  2019    2    Nation     NaN  U.S. TOTAL
# 2      US000  US   0.0    2     10  2019    2    Nation     NaN  U.S. TOTAL
# 3      US000  US   0.0    3     10  2019    2    Nation     NaN  U.S. TOTAL
# 4      US000  US   0.0    5     10  2019    2    Nation     NaN  U.S. TOTAL
#
#    ...                  Industry Status Code Establishment Count  \
# 0  ...  10 Total, all industries         NaN          10,224,644
# 1  ...  10 Total, all industries         NaN              59,645
# 2  ...  10 Total, all industries         NaN              69,745
# 3  ...  10 Total, all industries         NaN             171,014
# 4  ...  10 Total, all industries         NaN           9,924,240
#
#   April Employment May Employment June Employment Total Quarterly Wages  \
# ...

# %%
new_employment_data2 = employment_data2[['Area Type','St Name','Industry','Establishment Count','Total Quarterly Wages']].copy()
new_employment_data2.head()
# Out:
#   Area Type St Name                  Industry Establishment Count  \
# 0    Nation     NaN  10 Total, all industries          10,224,644
# 1    Nation     NaN  10 Total, all industries              59,645
# 2    Nation     NaN  10 Total, all industries              69,745
# 3    Nation     NaN  10 Total, all industries             171,014
# 4    Nation     NaN  10 Total, all industries           9,924,240
#
#   Total Quarterly Wages
# 0     2,112,045,195,311
# 1        59,731,515,719
# 2        72,198,314,422
# 3       197,372,310,643
# 4     1,782,743,054,527

# %%
csv_file3 = "Resources/allhlcn193.csv"
employment_data3 = pd.read_csv(csv_file3)

# %%
new_employment_data3 = employment_data3[['Area Type','St Name','Industry','Establishment Count','Total Quarterly Wages']].copy()
new_employment_data3.head()
# Out:
#   Area Type St Name                  Industry Establishment Count  \
# 0    Nation     NaN  10 Total, all industries          10,325,274
# 1    Nation     NaN  10 Total, all industries              61,270
# 2    Nation     NaN  10 Total, all industries              70,371
# 3    Nation     NaN  10 Total, all industries             171,239
# 4    Nation     NaN  10 Total, all industries          10,022,394
#
#   Total Quarterly Wages
# 0     2,101,499,510,734
# 1        59,190,776,379
# 2        73,759,826,809
# 3       173,546,564,339
# 4     1,795,002,343,207

# %%
new_employment_data = pd.merge(new_employment_data1, new_employment_data2, on='Area Type')
new_employment_data
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-14-12c3c95bf4b2> in <module>
# ----> 1 new_employment_data = pd.merge(new_employment_data1, new_employment_data2, on='Area Type')
#       2 new_employment_data
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      81         validate=validate,
#      82     )
# ---> 83     return op.get_result()
#      84
#      85
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     640             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     641
# --> 642         join_index, left_indexer, right_indexer = self._get_join_info()
#     643
#     644         ldata, rdata = self.left._data, self.right._data
#
# ...

# %%
q2 = new_employment_data2['Total Quarterly Wages']
q3 = new_employment_data3['Total Quarterly Wages']
new_employment_data = pd.DataFrame[]
